# %% [markdown]
# # Assignment 3: Dictionaries and Functions
#
# **EXAMPLE SOLUTION: NOT TO SHARE WITH STUDENTS**

# %% [markdown]
# ## Task 1. (14 Points)
#
# The code below reads a text file containing an excerpt from the novel The Old Man and the Sea. The text is stored in a variable named text.

# %%
with open('theoldmanandthesea.txt', 'r') as f:
    text = f.read()

# %% [markdown]
# 1. Write a function that receives a text (as a single string) and returns a list containing all the words that appear in the text. You do not need to consider punctuation, just split by whitespace. The returned words should be in lowercase. (2 Points)

# %%
def list_words(text):
    return text.lower().split(" ")

list_words(text)
# Out:
# ['he',
#  'was',
#  'an',
#  'old',
#  'man',
#  'who',
#  'fished',
#  'alone',
#  'in',
#  'a',
#  'skiff',
#  'in',
#  'the',
#  'gulf',
#  'stream',
#  'and',
#  'he',
#  'had',
#  'gone',
#  'eighty-four',
#  'days',
#  'now',
#  'without',
#  'taking',
#  'a',
#  'fish.',
#  'in',
#  'the',
#  'first',
#  'forty',
#  'days',
#  'a',
#  'boy',
#  'had',
#  'been',
#  'with',
#  'him.',
#  'but',
#  'after',
#  'forty',
#  'days',
#  'without',
#  'a',
#  'fish',
#  'the',
#  "boy's",
#  'parents',
#  'had',
#  'told',
#  'him',
#  'that',
#  'the',
#  'old',
#  'man',
#  'was',
#  'now',
#  'definitely',
#  'and',
#  'finally',
#  'salao,',
#  'which',
#  'is',
#  'the',
#  'worst',
#  'form',
#  'of',
#  'unlucky,',
#  'and',
#  'the',
#  'boy',
#  'had',
#  'gone',
#  'at',
#  'their',
#  'orders',
#  'in',
#  'another',
#  'boat',
#  'which',
#  'caught',
#  'three',
#  'good',
#  'fish',
#  'the',
#  'first',
#  'week.',
#  'it',
#  'made',
#  'the',
#  'boy',
#  'sad',
#  'to',
#  'see',
#  'the',
#  'old',
#  'man',
#  'come',
#  'in',
#  'each',
#  'day',
#  'with',
#  'his',
#  'skiff',
#  'empty',
#  'and',
#  'he',
#  'always',
#  'went',
#  'down',
#  'to',
#  'help',
#  'him',
#  'carry',
#  'either',
#  'the',
#  'coiled',
#  'lines',
#  'or',
#  'the',
#  'gaff',
#  'and',
#  'harpoon',
#  'and',
#  'the',
#  'sail',
#  'that',
#  'was',
#  'furled',
#  'around',
#  'the',
#  'mast.',
#  'the',
#  'sail',
#  'was',
#  'patched',
#  'with',
#  'flour',
#  'sacks',
#  'and,',
#  'furled,',
#  'it',
#  'looked',
#  'like',
#  'the',
#  'flag',
#  'of',
#  'permanent',
#  'defeat.the',
#  'old',
#  'man',
#  'was',
#  'thin',
#  'and',
#  'gaunt',
#  'with',
#  'deep',
#  'wrinkles',
#  'in',
#  'the',
#  'back',
#  'of',
#  'his',
#  'neck.',
#  'the',
#  'brown',
#  'blotches',
#  'of',
#  'the',
#  'benevolent',
#  'skin',
#  'cancer',
#  'the',
#  'sun',
#  'brings',
#  'from',
#  'its',
#  'reflection',
#  'on',
#  'the',
#  'tropic',
#  'sea',
#  'were',
#  'on',
#  'his',
#  'cheeks.',
#  'the',
#  'blotches',
#  'ran',
#  'well',
#  'down',
#  'the',
#  'sides',
#  'of',
#  'his',
#  'face',
#  'and',
#  'his',
#  'hands',
#  'had',
#  'the',
#  'deep-creased',
#  'scars',
#  'from',
#  'handling',
#  'heavy',
#  'fish',
#  'on',
#  'the',
#  'cords.',
#  'but',
#  'none',
#  'of',
#  'these',
#  'scars',
#  'were',
#  'fresh.',
#  'they',
#  'were',
#  'as',
#  'old',
#  'as',
#  'erosions',
#  'in',
#  'a',
#  'fishless',
#  'desert.']

# %% [markdown]
# 2. Write a function that receives a list of words and returns a dictionary where each key is a word and the corresponding value is its count.  (5 points)

# %%
def word_dict1(wordlist):
    countsdic = dict()
    for word in wordlist:
        if countsdic.get(word, -1) == -1:
            countsdic[word] = 1
        else:
            countsdic[word] += 1
    return countsdic

# alternative with dictionary comprehension
def word_dict2(wordlist):
    return {x: wordlist.count(x) for x in wordlist if wordlist.count(x)>1}

# more elegant:
def word_dict3(word_list):
    result = {}
    for word in set(word_list):
        result[word] = word_list.count(word)
    return result

# %% [markdown]
# 3. Using the functions from Tasks 1 and 2, create a dictionary where the keys are the words that appear in the text (The Old Man and the Sea) and the values are the word counts. (1 point)

# %%
words = list_words(text)
counts = word_dict3(words)
counts
# Out:
# {'sea': 1,
#  'week.': 1,
#  'that': 2,
#  'salao,': 1,
#  'after': 1,
#  'come': 1,
#  'went': 1,
#  'either': 1,
#  'forty': 2,
#  'each': 1,
#  'days': 3,
#  'erosions': 1,
#  'without': 2,
#  'well': 1,
#  'him': 2,
#  'which': 2,
#  'parents': 1,
#  'hands': 1,
#  'around': 1,
#  'gone': 2,
#  'to': 2,
#  'deep': 1,
#  'deep-creased': 1,
#  'boat': 1,
#  'day': 1,
#  'on': 3,
#  'good': 1,
#  'skin': 1,
#  'him.': 1,
#  'lines': 1,
#  'furled': 1,
#  'brings': 1,
#  'sun': 1,
#  'desert.': 1,
#  'brown': 1,
#  'fish': 3,
#  'their': 1,
#  'blotches': 2,
#  'coiled': 1,
#  'gaunt': 1,
#  'orders': 1,
#  'back': 1,
#  'finally': 1,
#  'these': 1,
#  'worst': 1,
#  'down': 2,
#  'old': 5,
#  'heavy': 1,
#  'an': 1,
#  'like': 1,
#  'but': 2,
#  'now': 2,
#  'always': 1,
#  'boy': 3,
#  'fished': 1,
#  'three': 1,
#  'patched': 1,
#  'man': 4,
#  'who': 1,
#  'harpoon': 1,
#  'cancer': 1,
#  'cords.': 1,
#  'told': 1,
#  'it': 2,
#  'cheeks.': 1,
#  'form': 1,
#  'as': 2,
#  'thin': 1,
#  'in': 7,
#  'mast.': 1,
#  'handling': 1,
#  'fish.': 1,
#  "boy's": 1,
#  'permanent': 1,
#  'is': 1,
#  'sides': 1,
#  'first': 2,
#  'flour': 1,
#  'furled,': 1,
#  'with': 4,
#  'from': 2,
#  'eighty-four': 1,
#  'its': 1,
#  'a': 5,
#  'defeat.the': 1,
#  'they': 1,
#  'caught': 1,
#  'tropic': 1,
#  'stream': 1,
#  'sacks': 1,
#  'ran': 1,
#  'or': 1,
#  'wrinkles': 1,
#  'had': 5,
#  'empty': 1,
#  'been': 1,
#  'gaff': 1,
#  'and,': 1,
#  'scars': 2,
#  'help': 1,
#  'the': 24,
#  'was': 5,
#  'his': 5,
#  'definitely': 1,
#  'skiff': 2,
#  'fresh.': 1,
#  'taking': 1,
#  'and': 8,
#  'face': 1,
#  'sail': 2,
#  'at': 1,
#  'unlucky,': 1,
#  'flag': 1,
#  'none': 1,
#  'were': 3,
#  'carry': 1,
#  'reflection': 1,
#  'benevolent': 1,
#  'fishless': 1,
#  'made': 1,
#  'neck.': 1,
#  'see': 1,
#  'of': 6,
#  'sad': 1,
#  'gulf': 1,
#  'looked': 1,
#  'alone': 1,
#  'he': 3,
#  'another': 1}

# %% [markdown]
# 4. Using the dictionary you created for the previous task, print how many times each of the following words appears in the text. Use a for loop.  (2 points
# Words:
# ```python
#     ['the','old','man','in','the','sea']

# %%
words_to_check = ['the','old','man','in','the','sea']
for word in words_to_check:
    print(word + ": " + str(counts[word]))
# Out:
# the: 24
# old: 5
# man: 4
# in: 7
# the: 24
# sea: 1

# %% [markdown]
# 5. Create a sorted list of word-count pairs, ordered from the highest count to the lowest from the dictionary created in the task 3. Do this using a lambda function. (3 Points)
# 6. Print the top 10 most frequent words along with their counts. (1 Point)

# %%
countpairs = [(x,y) for (x,y) in counts.items()]
countpairs.sort(key=lambda x: x[1], reverse = True)
print(countpairs)

for i in range(10):
    print(countpairs[i])

# print(countpairs[0:9]) # Also fine
# Out:
# [('the', 24), ('and', 8), ('in', 7), ('of', 6), ('old', 5), ('a', 5), ('had', 5), ('was', 5), ('his', 5), ('man', 4), ('with', 4), ('days', 3), ('on', 3), ('fish', 3), ('boy', 3), ('were', 3), ('he', 3), ('that', 2), ('forty', 2), ('without', 2), ('him', 2), ('which', 2), ('gone', 2), ('to', 2), ('blotches', 2), ('down', 2), ('but', 2), ('now', 2), ('it', 2), ('as', 2), ('first', 2), ('from', 2), ('scars', 2), ('skiff', 2), ('sail', 2), ('sea', 1), ('week.', 1), ('salao,', 1), ('after', 1), ('come', 1), ('went', 1), ('either', 1), ('each', 1), ('erosions', 1), ('well', 1), ('parents', 1), ('hands', 1), ('around', 1), ('deep', 1), ('deep-creased', 1), ('boat', 1), ('day', 1), ('good', 1), ('skin', 1), ('him.', 1), ('lines', 1), ('furled', 1), ('brings', 1), ('sun', 1), ('desert.', 1), ('brown', 1), ('their', 1), ('coiled', 1), ('gaunt', 1), ('orders', 1), ('back', 1), ('finally', 1), ('these', 1), ('worst', 1), ('heavy', 1), ('an', 1), ('like', 1), ('always', 1), ('fished', 1), ('three', 1), ('patched', 1), ('who', 1), ('harpoon', 1), ('cancer', 1), ('cords.', 1), ('told', 1), ('cheeks.', 1), ('form', 1), ('thin', 1), ('mast.', 1), ('handling', 1), ('fish.', 1), ("boy's", 1), ('permanent', 1), ('is', 1), ('sides', 1), ('flour', 1), ('furled,', 1), ('eighty-four', 1), ('its', 1), ('defeat.the', 1), ('they', 1), ('caught', 1), ('tropic', 1), ('stream', 1), ('sacks', 1), ('ran', 1), ('or', 1), ('wrinkles', 1), ('empty', 1), ('been', 1), ('gaff', 1), ('and,', 1), ('help', 1), ('definitely', 1), ('fresh.', 1), ('taking', 1), ('face', 1), ('at', 1), ('unlucky,', 1), ('flag', 1), ('none', 1), ('carry', 1), ('reflection', 1), ('benevolent', 1), ('fishless', 1), ('made', 1), ('neck.', 1), ('see', 1), ('sad', 1), ('gulf', 1), ('looked', 1), ('alone', 1), ('another', 1)]
# ('the', 24)
# ('and', 8)
# ('in', 7)
# ('of', 6)
# ('old', 5)
# ('a', 5)
# ('had', 5)
# ('was', 5)
# ('his', 5)
# ('man', 4)

# %% [markdown]
# ## Task 2. (6 Points)
# We have data on five Twitter users stored in a list. Each user's list contains the following information: name, number of followers, and a list of retweets with the information of followers that retweeted the user. Your task is to create a dictionary named **overall_users** in the specified format (without manually typing all the data):
#
# ```python
# {'gabby': {'name': 'gabby',
#   'follower_num': 13,
#   'retweet_users': ['b', 'c', 'e', 'h', 'r', 'b', 'b', 'c', 'h']},
#  'kitty': {'name': 'kitty',
#   'follower_num': 10,
#   'retweet_users': ['a', 'c', 'a', 'h', 'z']},
#  'pandy': {'name': 'pandy',
#   'follower_num': 5,
#   'retweet_users': ['a', 'd', 'd']},
#  'babybox': {'name': 'babybox',
#   'follower_num': 7,
#   'retweet_users': ['a', 'b', 'e', 'a']},
#  'cakey': {'name': 'cakey',
#   'follower_num': 6,
#   'retweet_users': ['d', 'c', 'b', 'b']}}
# ```

# %%
user_a = ['gabby', 13 ,['b','c','e','h','r','b']] # User A is retweeted by ''user B, C, E, H...
user_b = ['kitty', 10, ['a','c','a','h','z']] # User B is retweeted by user A, C, A,...
user_c = ['pandy', 5, ['a','d','d']]
user_d = ['babybox',7,['a','b','e','a']]
user_e = ['cakey',6,['d','c','b','b']]

# %% [markdown]
# 1. Write a function that receives the list corresponding to one user as an argument and returns a dictionary in the following format. (3 Points)
# ```python
#     {'name': 'gabby',
#     'follower_num': 13,
#     'retweet_users': ['b', 'c', 'e', 'h', 'r', 'b', 'b', 'c', 'h']}

# %%
def to_json(userlist):
    userjson = dict()
    userjson["name"] = userlist[0]
    userjson["follower_num"] = userlist[1]
    userjson["retweet_users"] = userlist[2]
    return(userjson)

to_json(user_a)
# Out:
# {'name': 'gabby',
#  'follower_num': 13,
#  'retweet_users': ['b', 'c', 'e', 'h', 'r', 'b']}

# %% [markdown]
# 2. Using the function from the above task, create a **overall_users** dictionary that contains all the user information. (1 Point)

# %%
overall_users = dict()
overall_users[user_a[0]] = to_json(user_a)
overall_users[user_b[0]] = to_json(user_b)
overall_users[user_c[0]] = to_json(user_c)
overall_users[user_d[0]] = to_json(user_d)
overall_users[user_e[0]] = to_json(user_e)
print(overall_users)
# Out:
# {'gabby': {'name': 'gabby', 'follower_num': 13, 'retweet_users': ['b', 'c', 'e', 'h', 'r', 'b']}, 'kitty': {'name': 'kitty', 'follower_num': 10, 'retweet_users': ['a', 'c', 'a', 'h', 'z']}, 'pandy': {'name': 'pandy', 'follower_num': 5, 'retweet_users': ['a', 'd', 'd']}, 'babybox': {'name': 'babybox', 'follower_num': 7, 'retweet_users': ['a', 'b', 'e', 'a']}, 'cakey': {'name': 'cakey', 'follower_num': 6, 'retweet_users': ['d', 'c', 'b', 'b']}}

# %%
all_users = [user_a,user_b,user_c,user_d,user_e]

overall_users = {}
for user in all_users:
    overall_users[user[0]] = to_json(user)
print(overall_users)
# Out:
# {'gabby': {'name': 'gabby', 'follower_num': 13, 'retweet_users': ['b', 'c', 'e', 'h', 'r', 'b']}, 'kitty': {'name': 'kitty', 'follower_num': 10, 'retweet_users': ['a', 'c', 'a', 'h', 'z']}, 'pandy': {'name': 'pandy', 'follower_num': 5, 'retweet_users': ['a', 'd', 'd']}, 'babybox': {'name': 'babybox', 'follower_num': 7, 'retweet_users': ['a', 'b', 'e', 'a']}, 'cakey': {'name': 'cakey', 'follower_num': 6, 'retweet_users': ['d', 'c', 'b', 'b']}}

# %% [markdown]
# 3. We have additional data on retweets. There are new users who retweeted user_a's posts. Update the **overall_users** dictionary to include this information. (2 Point)
#
#    Additional users who retweeted user_a's posts:
#    ```python
#    ['s','g']

# %%
overall_users[user_a[0]]["retweet_users"].extend(["s","g"])  # two appends also valid
print(overall_users)
# Out:
# {'gabby': {'name': 'gabby', 'follower_num': 13, 'retweet_users': ['b', 'c', 'e', 'h', 'r', 'b', 's', 'g']}, 'kitty': {'name': 'kitty', 'follower_num': 10, 'retweet_users': ['a', 'c', 'a', 'h', 'z']}, 'pandy': {'name': 'pandy', 'follower_num': 5, 'retweet_users': ['a', 'd', 'd']}, 'babybox': {'name': 'babybox', 'follower_num': 7, 'retweet_users': ['a', 'b', 'e', 'a']}, 'cakey': {'name': 'cakey', 'follower_num': 6, 'retweet_users': ['d', 'c', 'b', 'b']}}

# %%
overall_users[user_a[0]]["retweet_users"].append(["s","g"])  # two appends also valid
print(overall_users)
# Out:
# {'gabby': {'name': 'gabby', 'follower_num': 13, 'retweet_users': ['b', 'c', 'e', 'h', 'r', 'b', ['s', 'g']]}, 'kitty': {'name': 'kitty', 'follower_num': 10, 'retweet_users': ['a', 'c', 'a', 'h', 'z']}, 'pandy': {'name': 'pandy', 'follower_num': 5, 'retweet_users': ['a', 'd', 'd']}, 'babybox': {'name': 'babybox', 'follower_num': 7, 'retweet_users': ['a', 'b', 'e', 'a']}, 'cakey': {'name': 'cakey', 'follower_num': 6, 'retweet_users': ['d', 'c', 'b', 'b']}}
